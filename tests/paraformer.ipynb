# %%
from modelscope.pipelines import pipeline
from modelscope.utils.constant import Tasks
# Out:
# /home/delta/anaconda3/envs/modelscope/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /home/delta/anaconda3/envs/modelscope/lib/python3.8/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warn(f"Failed to load image Python extension: {e}")

# %%
inference_pipeline = pipeline(
    task=Tasks.auto_speech_recognition,
    model='iic/speech_paraformer-large_asr_nat-zh-cn-16k-common-vocab8404-pytorch', model_revision="v2.0.5")
# Out:
# ...
# 2024-11-19 02:25:30,005 - modelscope - INFO - Use user-specified model revision: v2.0.5
# 2024-11-19 02:25:30,391 - modelscope - INFO - initiate model from /home/delta/.cache/modelscope/hub/iic/speech_paraformer-large_asr_nat-zh-cn-16k-common-vocab8404-pytorch
# 2024-11-19 02:25:30,392 - modelscope - INFO - initiate model from location /home/delta/.cache/modelscope/hub/iic/speech_paraformer-large_asr_nat-zh-cn-16k-common-vocab8404-pytorch.
# 2024-11-19 02:25:30,396 - modelscope - INFO - initialize model from /home/delta/.cache/modelscope/hub/iic/speech_paraformer-large_asr_nat-zh-cn-16k-common-vocab8404-pytorch
# Key Conformer already exists in model_classes, re-register
# Key Linear already exists in adaptor_classes, re-register
# Key TransformerDecoder already exists in decoder_classes, re-register
# Key LightweightConvolutionTransformerDecoder already exists in decoder_classes, re-register
# ...

# %%
rec_result = inference_pipeline(input='https://isv-data.oss-cn-hangzhou.aliyuncs.com/ics/MaaS/ASR/test_audio/asr_example_zh.wav')
print(rec_result)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]/home/delta/anaconda3/envs/modelscope/lib/python3.8/site-packages/funasr/models/paraformer/model.py:251: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(False):
# /home/delta/anaconda3/envs/modelscope/lib/python3.8/site-packages/funasr/models/paraformer/cif_predictor.py:212: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(False):
# rtf_avg: 0.085: 100%|██████████| 1/1 [00:00<00:00,  2.09it/s]
# [{'key': 'asr_example_zh', 'text': '欢迎大家来体验达摩院推出的语音识别模型'}]

# %%
rec_result = inference_pipeline(input='t1112.mp3')
print(rec_result)
# Out:
# [src/libmpg123/parse.c:skip_junk():1276] error: Giving up searching valid MPEG header after 65536 bytes of junk.
# /home/delta/anaconda3/envs/modelscope/lib/python3.8/site-packages/funasr/models/paraformer/model.py:251: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(False):
# /home/delta/anaconda3/envs/modelscope/lib/python3.8/site-packages/funasr/models/paraformer/cif_predictor.py:212: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(False):
# rtf_avg: 0.081: 100%|██████████| 1/1 [00:00<00:00,  1.66it/s]
# [{'key': 't1112', 'text': '螺旋桨拆装检查并调整平衡'}]
